# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data=pd.read_csv("House_Rent_Dataset.csv")
data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area  \
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family  \
# ...

# %%
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area  \
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family  \
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
data.describe().T
# Out:
#            count          mean           std     min      25%      50%
# BHK       4746.0      2.083860      0.832256     1.0      2.0      2.0  \
# Rent      4746.0  34993.451327  78106.412937  1200.0  10000.0  16000.0
# Size      4746.0    967.490729    634.202328    10.0    550.0    850.0
# Bathroom  4746.0      1.965866      0.884532     1.0      1.0      2.0
#
#               75%        max
# BHK           3.0        6.0
# Rent      33000.0  3500000.0
# Size       1200.0     8000.0
# Bathroom      2.0       10.0

# %%
data.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.plot(kind = "box" , subplots = True , figsize = (25,15) , layout = (5,5))
# Out:
# BHK            Axes(0.125,0.747241;0.133621x0.132759)
# Rent        Axes(0.285345,0.747241;0.133621x0.132759)
# Size         Axes(0.44569,0.747241;0.133621x0.132759)
# Bathroom    Axes(0.606034,0.747241;0.133621x0.132759)
# dtype: object

# %%
px.pie(data, names='Furnishing Status', title='Furnishing Status',color_discrete_sequence=px.colors.sequential.YlGnBu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
px.pie(data, names='Tenant Preferred', title='Tenant Preferred',color_discrete_sequence=px.colors.sequential.Greens_r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
data['Furnishing Status'].value_counts()
# Out:
# Furnishing Status
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: count, dtype: int64

# %%
px.pie(data, values='Rent', names='Furnishing Status',
             color_discrete_map={'Semi-Furnished':'cyan',
                                 'Unfurnished':'royalblue',
                                 'Furnished':'darkblue'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
px.pie(data,names='Area Type',title='Area Type',color_discrete_sequence=px.colors.sequential.Aggrnyl)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\sudha\Desktop\PythonCodes\venv\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
sns.histplot(data[''],kde=True)
# Out:
# <Axes: xlabel='Rent', ylabel='Count'>

# %%
df=data.copy()
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area  \
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family  \
# ...

# %%
sns.boxplot(df['Rent'])
# Out:
# <Axes: >

# %%
sns.barplot(x='BHK',y='Rent',data=df)
# Out:
# <Axes: xlabel='BHK', ylabel='Rent'>

# %%
sns.barplot(data=df, x="City", y="Rent")
# Out:
# <Axes: xlabel='City', ylabel='Rent'>

# %%
sns.histplot(data=df, x="Point of Contact")
# Out:
# <Axes: xlabel='Point of Contact', ylabel='Count'>

# %%
sns.barplot(data=df, x="Bathroom", y="Rent")
# Out:
# <Axes: xlabel='Bathroom', ylabel='Rent'>

# %%
sns.scatterplot(data=df, x="Point of Contact", y="Rent")
# Out:
# <Axes: xlabel='Point of Contact', ylabel='Rent'>

# %%
df.drop(['Area Locality','Floor','Posted On'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
cols = ['Area Type', 'City','Furnishing Status','Tenant Preferred','Point of Contact',]

df[cols] = df[cols].apply(LabelEncoder().fit_transform)

print(df['Area Type'].unique())
print(df['City'].unique())
print(df['Furnishing Status'].unique())
print(df['Tenant Preferred'].unique())
print(df['Point of Contact'].unique())
# Out:
# [2 1 0]
# [4 5 0 2 1 3]
# [2 1 0]
# [1 0 2]
# [2 0 1]

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df.corr() , annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('Rent',axis=1).values
y = df['Rent'].values

# %%
x_train ,x_test ,y_train ,y_test=train_test_split(x,y ,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (3796, 8)

# %%
x_test.shape
# Out:
# (950, 8)

# %% [markdown]
# MODELING

# %%
from sklearn.preprocessing import StandardScaler
print(x_test)
# Out:
# [[   2 1100    2 ...    1    2    2]
#  [   2  800    2 ...    1    2    2]
#  [   2  518    1 ...    1    2    2]
#  ...
#  [   2  950    2 ...    1    2    2]
#  [   3 1125    2 ...    1    2    2]
#  [   1  500    2 ...    1    1    2]]

# %%
ss=StandardScaler()
x_train =ss.fit_transform(x_train)
x_test=ss.fit_transform(x_test)

# %%
print(x_test)
# Out:
# [[-0.07190771  0.20768746  0.97299605 ...  0.12935128  0.05042936
#    0.69097717]
#  [-0.07190771 -0.26818505  0.97299605 ...  0.12935128  0.05042936
#    0.69097717]
#  [-0.07190771 -0.71550522 -1.0277534  ...  0.12935128  0.05042936
#    0.69097717]
#  ...
#  [-0.07190771 -0.03024879  0.97299605 ...  0.12935128  0.05042936
#    0.69097717]
#  [ 1.1701346   0.24734351  0.97299605 ...  0.12935128  0.05042936
#    0.69097717]
#  [-1.31395003 -0.74405757  0.97299605 ...  0.12935128 -1.09023479
#    0.69097717]]

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest=RandomForestRegressor()
random_forest.fit(x_train , y_train)
print("Random Forest Training Accuracy:", str((random_forest.score(x_train , y_train))*100)+'%')
print("Random Forest Testing Accuracy:", str((random_forest.score(x_test , y_test))*100)+'%')
# Out:
# Random Forest Training Accuracy: 88.71486039062732%
# Random Forest Testing Accuracy: 34.40529735977115%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   int64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   int64
#  3   Area Type          4746 non-null   int64
#  4   City               4746 non-null   int64
#  5   Furnishing Status  4746 non-null   int64
#  6   Tenant Preferred   4746 non-null   int64
#  7   Bathroom           4746 non-null   int64
#  8   Point of Contact   4746 non-null   int64
# dtypes: int64(9)
# memory usage: 333.8 KB

# %%
# y_pred = random_forest.predict([['2','3','5','7','3','2','1','2']])
y_pred = random_forest.predict(x_test)

# %%
print(y_pred)
# Out:
# [ 17428.12698413  15545.86188095  32385.          50012.5
#  104130.          17017.33333333  56075.91728571  12886.13507326
#  297794.76190476  12093.5         13452.38095238  10164.83333333
#   17006.41666667  15314.56190476  21741.66666667  30065.
#  109710.           7964.49705861  18503.32142857  42461.5
#   31105.           7121.49007937  43934.16666667  14664.09722222
#  132646.66666667   7604.75         7751.65975236  30605.
#    9795.30952381  12725.           7380.41550201   7171.02380952
#    7373.16666667  17328.33333333  21760.          28755.
#    6598.28888889   7209.51181662  13983.65633474   8156.84717405
#   13887.53778892 311966.66666667  22003.66666667   6896.98913586
#   58226.49603175  10572.13156166  41878.34333333  88166.66666667
#  601300.          27943.33333333  10285.56474845  24873.83333333
#   16061.66666667  15896.66666667  32153.66666667 195600.
#   37760.          51440.          10360.          15049.41666667
# ...
